# %%
import requests as r
import json
res1 = r.get("https://developers.zomato.com/api/v2.1/cities",params={'q': 'kanpur'}, headers= {'user-key': '3e75e173fb9e09b2e40e49575b2af392','Accept': 'application/json'})
res1.json()
# Out:
# {'location_suggestions': [{'id': 23,
#    'name': 'Kanpur',
#    'country_id': 1,
#    'country_name': 'India',
#    'country_flag_url': 'https://b.zmtcdn.com/images/countries/flags/country_1.png',
#    'should_experiment_with': 0,
#    'has_go_out_tab': 0,
#    'discovery_enabled': 0,
#    'has_new_ad_format': 1,
#    'is_state': 0,
#    'state_id': 0,
#    'state_name': '',
#    'state_code': ''}],
#  'status': 'success',
#  'has_more': 0,
#  'has_total': 0,
#  'user_has_addresses': True}

# %%
res = r.get("https://developers.zomato.com/api/v2.1/cuisines", params={'city_id':23}, headers= {'user-key': '3e75e173fb9e09b2e40e49575b2af392','Accept': 'application/json'})
py_data=res.json()
for x in range(len(py_data['cuisines'])):
    if py_data['cuisines'][x]['cuisine']['cuisine_name']=='Mexican':
        print(py_data['cuisines'][x]['cuisine']['cuisine_id'])
# Out:
# 73

# %%
res = r.get("https://developers.zomato.com/api/v2.1//locations",params={'query':'Connaught Place'}, headers= {'user-key': '3e75e173fb9e09b2e40e49575b2af392','Accept': 'application/json'})
py_data=res.json()
print(py_data['location_suggestions'][0]['entity_type'],py_data['location_suggestions'][0]['entity_id'])
# Out:
# subzone 104

# %%
res = r.get("https://developers.zomato.com/api/v2.1/search",params={'entity_id':104, 'entity_type':'subzone', 'cuisines':'73', 'sort':'rating', 'order':'desc'}, headers= {'user-key': '3e75e173fb9e09b2e40e49575b2af392','Accept': 'application/json'})
py_data=res.json()
for x in range(10):
    print(py_data['restaurants'][x]['restaurant']['name'], py_data['restaurants'][x]['restaurant']['user_rating']['aggregate_rating'], py_data['restaurants'][x]['restaurant']['R']['res_id'] )
#py_data['restaurants'][0]['restaurant']['R']['res_id']
# Out:
# Farzi Cafe 4.5 18233593
# Ministry Of Beer 4.4 18418277
# Chili's Grill & Bar 4.4 18537536
# Warehouse Cafe 4.3 301605
# Xero Degrees 4.3 18729557
# Unplugged Courtyard 4.2 18216901
# Pebble Street 4.2 309859
# Chaayos - Meri Wali Chai 4.2 18237315
# The Beer Cafe - BIGGIE 4.2 307060
# Rodeo Cantina & Kitchen 4.1 18673403

# %%
res = r.get("https://developers.zomato.com/api/v2.1/categories", headers= {'user-key': '3e75e173fb9e09b2e40e49575b2af392','Accept': 'application/json'})
py_data=res.json()
for x in range(len(py_data['categories'])):
    if py_data['categories'][x]['categories']['name']=='Cafes':
        print(py_data['categories'][x]['categories']['id'])
# Out:
# 6

# %%
res = r.get("https://developers.zomato.com/api/v2.1/search",params={'entity_id':104, 'entity_type':'subzone', 'cuisines':'73', 'sort':'rating', 'order':'desc', 'category':'6'}, headers= {'user-key': '3e75e173fb9e09b2e40e49575b2af392','Accept': 'application/json'})
py_data=res.json()
#print(py_data['restaurants'][0]['restaurant']['name'], py_data['restaurants'][0]['restaurant']['user_rating']['aggregate_rating'], py_data['restaurants'][0]['restaurant']['R']['res_id'] )
#for x in range(len(py_data['restaurants'])):
#    print(py_data['restaurants'][x]['restaurant']['name'], py_data['restaurants'][x]['restaurant']['user_rating']['aggregate_rating'], py_data['restaurants'][x]['restaurant']['R']['res_id'] )
# Out:
# Xero Degrees 4.3 18729557
# Chaayos - Meri Wali Chai 4.2 18237315
# The Art House Bar n Cafe 4.0 18863766
# Cafe Coffee Day - The Square 3.5 303034

# %%
res = r.get("https://developers.zomato.com/api/v2.1/reviews",params={'res_id':18729557}, headers= {'user-key': '3e75e173fb9e09b2e40e49575b2af392','Accept': 'application/json'})
py_data=res.json()
for x in range(len(py_data['user_reviews'])):
    print(py_data['user_reviews'][x]['review']['user']['name'],py_data['user_reviews'][x]['review']['rating'],py_data['user_reviews'][x]['review']['review_text'])
#py_data['user_reviews'][0]['review']['user']['name']
#py_data['user_reviews'][0]['review']['review_text']
# Out:
# Tarun 5 Fantastically amazing !! tried cheese fries, peri peri fries, arabita pasta and Alfredo tooo. All were presented beautifully, taste was also upto the mark.  Talking about whole dining review, music was light, seatings were good and a student friendly ambiance and price point. Service could have been better or speedy, but i understand preparing such a delight takes time. So 10/10 in every aspect. Must try 🔥
# Purnima Saini 3 I was so excited to visit this place but was disappointed...  I dint like the seating of this place as it was very uncomfortable. I had blueberry shake which I dint like but chocolate shakes were good...  Fries were also good and I had the pizza in a jar... Food was ok and serving was really good....
# Prachi Kataria 5 Nice range of shakes and drink 👍 great quality of food 👍 nice vibes , great service  , nice staff
# ...

# %%
res = r.get("https://developers.zomato.com/api/v2.1/search",params={'entity_id':104, 'entity_type':'subzone', 'cuisines':'73', 'sort':'rating', 'order':'desc'}, headers= {'user-key': '3e75e173fb9e09b2e40e49575b2af392','Accept': 'application/json'})
py_data=res.json()
for x in range(10):
    print(py_data['restaurants'][x]['restaurant']['name'], py_data['restaurants'][x]['restaurant']['user_rating']['aggregate_rating'], py_data['restaurants'][x]['restaurant']['R']['res_id'] )

# %%
#start
res1 = r.get("https://developers.zomato.com/api/v2.1/cities",params={'q': 'delhi ncr'}, headers= {'user-key': '3e75e173fb9e09b2e40e49575b2af392','Accept': 'application/json'})
city_id=res1.json()['location_suggestions'][0]['id']
# Out:
# 1

# %%
res = r.get("https://developers.zomato.com/api/v2.1/cuisines", params={'city_id':city_id}, headers= {'user-key': '3e75e173fb9e09b2e40e49575b2af392','Accept': 'application/json'})
py_data=res.json()
for x in range(len(py_data['cuisines'])):
    if py_data['cuisines'][x]['cuisine']['cuisine_name']=='Asian':
        cuisine_id = py_data['cuisines'][x]['cuisine']['cuisine_id']

# %%
res = r.get("https://developers.zomato.com/api/v2.1//locations",params={'query':'Delhi'}, headers= {'user-key': '3e75e173fb9e09b2e40e49575b2af392','Accept': 'application/json'})
py_data=res.json()
entity_type = py_data['location_suggestions'][0]['entity_type']
entity_id = py_data['location_suggestions'][0]['entity_id']

# %%
res = r.get("https://developers.zomato.com/api/v2.1/search",params={'entity_id':entity_id, 'entity_type':entity_type, 'cuisines':cuisine_id}, headers= {'user-key': '3e75e173fb9e09b2e40e49575b2af392','Accept': 'application/json'})
py_data=res.json()
for x in range(len(py_data['restaurants'])):
    if py_data['restaurants'][x]['restaurant']['name']=='Pa Pa Ya':
        res_id = py_data['restaurants'][x]['restaurant']['R']['res_id']

# %%
res = r.get("https://developers.zomato.com/api/v2.1/restaurant",params={'res_id': res_id}, headers= {'user-key': '3e75e173fb9e09b2e40e49575b2af392','Accept': 'application/json'})
py_data=res.json()
print(py_data['user_rating']['aggregate_rating'])
print(py_data['average_cost_for_two'])
print(py_data['cuisines'])
print(py_data['location']['address'])
#res_id=18429148
# Out:
# 4.9
# 2500
# Asian, Chinese, Thai, Japanese
# A-3, Select Citywalk, District Centre, Saket, New Delhi

# %%
res = r.get("https://developers.zomato.com/api/v2.1/restaurant",params={'res_id': res_id}, headers= {'user-key': '3e75e173fb9e09b2e40e49575b2af392','Accept': 'application/json'})
py_data=res.json()
boolean = py_data['is_table_reservation_supported']
if boolean==1:
    print('yes')
else:
    print('no')
# Out:
# yes

# %%
res = r.get("https://developers.zomato.com/api/v2.1/cuisines", params={'city_id':23}, headers= {'user-key': '3e75e173fb9e09b2e40e49575b2af392','Accept': 'application/json'})
py_data=res.json()
for x in range(len(py_data['cuisines'])):
    if py_data['cuisines'][x]['cuisine']['cuisine_name']=='BBQ':
        print(py_data['cuisines'][x]['cuisine']['cuisine_id'])
# Out:
# 193

# %%
res = r.get("https://developers.zomato.com/api/v2.1/search",params={'cuisines': 193,'lat':28.6977, 'lon':77.1406, 'sort':'real_distance', 'order':'asc'}, headers= {'user-key': '3e75e173fb9e09b2e40e49575b2af392','Accept': 'application/json'})
py_data=res.json()
for x in range(10):
    print(py_data['restaurants'][x]['restaurant']['name'], py_data['restaurants'][x]['restaurant']['user_rating']['aggregate_rating'],py_data['restaurants'][x]['restaurant']['R']['res_id'], py_data['restaurants'][x]['restaurant']['location']['locality'] )
py_data
# Out:
# Themis Barbecue House 4.3 18204820 Netaji Subhash Place
# Barbeque Nation 4.6 9561 Netaji Subhash Place
# Amazings Kitchen 0 19370424 Prashant Vihar
# Moet's Barbeque 0 19238917 Alipur
# UBQ by Barbeque Nation 3.1 18889760 Rohini
# Kays Bar-Be-Que 3.9 3079 Ashok Vihar Phase 1
# Chicken Adda 0 19179179 Rohini
# 7teen BBQ Bistro Bnq 3.9 18595610 Moti Nagar
# Pishori Chicken 0 19061375 Kirti Nagar
# Hunger On Wheels 0 19054336 Vijay Nagar
# {'results_found': 122,
#  'results_start': 0,
#  'results_shown': 20,
#  'restaurants': [{'restaurant': {'R': {'has_menu_status': {'delivery': -1,
#       'takeaway': -1},
#      'res_id': 18204820,
#      'is_grocery_store': False},
#     'apikey': '3e75e173fb9e09b2e40e49575b2af392',
#     'id': '18204820',
#     'name': 'Themis Barbecue House',
#     'url': 'https://www.zomato.com/ncr/themis-barbecue-house-netaji-subhash-place-new-delhi?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
# ...

# %%
res = r.get("https://developers.zomato.com/api/v2.1/reviews",params={'res_id':18204820}, headers= {'user-key': '3e75e173fb9e09b2e40e49575b2af392','Accept': 'application/json'})
py_data=res.json()
for x in range(len(py_data['user_reviews'])):
    print(py_data['user_reviews'][x]['review']['user']['name'],py_data['user_reviews'][x]['review']['rating'],py_data['user_reviews'][x]['review']['review_text'])
# Out:
# Milind 4 If u are bored of Barbeque nation , this place is must try for u🤓🔥😅. It is one of the best barbeque restaurants in Delhi offering rooftop seating . So we opted for rooftop seating for our lunch & the view was amazing 🔥😻. We opted for veg buffet which included a range of starters like crispy corn , paneer tikka , spicy mushroom . Then in main course we tried manchurian with noodles . As a complementary drink I ordered Kiwi mojito which was so refreshing & eye catchy too😻🔥🔥🔥🤓🤓. So if u visit Pitampura next time don't miss this amazing place.👻🔥🤓😻😻
# Shashank Agarwal 4 Great place for an experience of grill in north delhi. Great starters, nice main course and average dessert.
# ...

# %%
res = r.get("https://developers.zomato.com/api/v2.1/search",params={'radius':4000.0,'lat':28.6977, 'lon':77.1406, 'sort':'rating', 'order':'desc'}, headers= {'user-key': '3e75e173fb9e09b2e40e49575b2af392','Accept': 'application/json'})
py_data=res.json()
for x in range(10):
    print(py_data['restaurants'][x]['restaurant']['name'], py_data['restaurants'][x]['restaurant']['user_rating']['aggregate_rating'],py_data['restaurants'][x]['restaurant']['R']['res_id'], py_data['restaurants'][x]['restaurant']['location']['locality'] )
#py_data
# Out:
# Indian Accent 4.9 2004 The Lodhi, Lodhi Road
# The Big Chill 4.9 1614 Khan Market
# Pa Pa Ya 4.9 18429148 Select Citywalk Mall, Saket
# Kuremal Mohan Lal Kulfi Wale 4.9 303642 Chawri Bazar
# Dum-Pukht - ITC Maurya 4.9 2744 ITC Maurya, Chanakyapuri
# The Big Chill 4.9 8244 Khan Market
# Wenger's 4.8 4249 Connaught Place
# Manhattan Bar & Brewery 4.8 303960 Global Foyer Mall, Golf Course Road
# Natural Ice Cream 4.8 310143 Connaught Place
# Downtown - Diners & Living Beer Cafe 4.8 4959 Sector 29
